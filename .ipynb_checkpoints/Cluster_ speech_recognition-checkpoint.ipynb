# %%
# from pythainlp import word_tokenize
# from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
# from pythainlp.word_vector import thai2vec 
import numpy as np
import pandas as pd
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

from pythainlp.tokenize import word_tokenize,sent_tokenize
from gensim.models import KeyedVectors
from gensim.models import Word2Vec
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.manifold import TSNE
from sklearn.cluster import AgglomerativeClustering
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from scipy.cluster import hierarchy
import dill as pickle
import pandas as pd
import pythainlp.word_vector
# model = word_vector.get_model()
model_path = 'thwiki_data/models/'

# %%
df = pd.read_csv("data/dataReV3.csv")

# %%
df
# Out:
#           Vehicle                                         restaurant  \
# 0            เดิน  ก๋วยเตี๋ยว, อาหารตามสั่ง, ข้าวมันไก่, ข้าวราดแ...
# 1   รถยนต์ส่วนตัว  ก๋วยเตี๋ยว, อาหารตามสั่ง, ข้าวมันไก่, ข้าวราดแ...
# 2            เดิน  ก๋วยเตี๋ยว, อาหารตามสั่ง, ข้าวราดแกง, ร้านน้ำ,...
# 3            เดิน  ก๋วยเตี๋ยว, อาหารตามสั่ง, ข้าวราดแกง, ร้านน้ำ,...
# 4      รถประจำทาง  ก๋วยเตี๋ยว, อาหารตามสั่ง, ข้าวมันไก่, ข้าวราดแ...
# ..            ...                                                ...
# 64  รถจักรยานยนต์                                                NaN
# 65  รถยนต์ส่วนตัว  ก๋วยเตี๋ยว, อาหารตามสั่ง, ข้าวมันไก่, ข้าวราดแ...
# 66  รถยนต์ส่วนตัว                                                NaN
# 67           เดิน                                                NaN
# 68  รถยนต์ส่วนตัว  ก๋วยเตี๋ยว, อาหารตามสั่ง, ข้าวมันไก่, ข้าวราดแ...
#
#                                         food delivery  \
# 0                                          Promotions
# 1                            หิว ขี้เกียจเดิน จะทำงาน
# 2   เพราะร้านที่อยากกินอยู่ไกล บางทีก็อยู่ในเวลาเร...
# 3                         ขี้เกียจเดินออกไปกินข้างนอก
# 4                                     อยากกินร้านนั้น
# ..                                                ...
# 64                                                NaN
# 65                                                NaN
# 66                                                NaN
# 67                                                NaN
# 68                                                NaN
#
#                                  Problem           work เวลาในการรออาหาร  \
# 0             ถ้าคนเยอะก็ไม่อยากไปต่อคิว  1 - 2 ชั่วโมง    10 นาทีขึ้นไป
# 1                       ไม่่มีอะไรน่ากิน  2 - 3 ชั่วโมง      6 - 10 นาที
# 2                     ถ้าคิวยาวก็ไม่ซื้อ  1 - 2 ชั่วโมง      6 - 10 นาที
# 3   ถ้าร้านนั้นคนเยอะก็จะไปเลือกร้านอื่น  1 - 2 ชั่วโมง      6 - 10 นาที
# 4             ถ้าแถวยาวมากก็จะขี้เกียจรอ  1 - 2 ชั่วโมง    10 นาทีขึ้นไป
# ..                                   ...            ...              ...
# 64                                   NaN            NaN              NaN
# 65                                   NaN            NaN              NaN
# 66                                   NaN            NaN              NaN
# 67                                   NaN            NaN              NaN
# 68                                   NaN            NaN              NaN
#
#       ราคาอาหาร
# 0     51-100บาท
# 1     51-100บาท
# 2   100-200 บาท
# 3   300-500 บาท
# 4   100-200 บาท
# ..          ...
# 64          NaN
# 65          NaN
# 66          NaN
# 67          NaN
# 68          NaN
#
# [69 rows x 7 columns]

# %%
df['Problem']
# Out:
# 0               ถ้าคนเยอะก็ไม่อยากไปต่อคิว
# 1                         ไม่่มีอะไรน่ากิน
# 2                       ถ้าคิวยาวก็ไม่ซื้อ
# 3     ถ้าร้านนั้นคนเยอะก็จะไปเลือกร้านอื่น
# 4               ถ้าแถวยาวมากก็จะขี้เกียจรอ
#                       ...
# 64                                     NaN
# 65                                     NaN
# 66                                     NaN
# 67                                     NaN
# 68                                     NaN
# Name: Problem, Length: 69, dtype: object

# %%
# .replace('มี',np.nan).dropna().values
text = df['Problem'].dropna()
text
# Out:
# 0                            ถ้าคนเยอะก็ไม่อยากไปต่อคิว
# 1                                      ไม่่มีอะไรน่ากิน
# 2                                    ถ้าคิวยาวก็ไม่ซื้อ
# 3                  ถ้าร้านนั้นคนเยอะก็จะไปเลือกร้านอื่น
# 4                            ถ้าแถวยาวมากก็จะขี้เกียจรอ
# 5                   ถ้าคนเยอะมากก็เปลี่ยนร้าน ไม่อยากรอ
# 6     ถ้าคนเยอะเกินไปก็จะไม่ซื้อ เปลี่ยนร้านหรือไม่ก...
# 7                                  ไม่มีร้านอาหารที่ชอบ
# 8               ขี้เกียจรอนานๆ แล้วรู้สึกว่ามันเสียเวลา
# 9                       ถ้าคิวยาวเกินจะเลือกร้านอื่นแทน
# 10                              เบื่อร้านอาหารที่มีอยู่
# 11                                 อยากกินอาหารแปลกใหม่
# 12                       โรงอาหารคนเยอะทำให้ไม่อยากซื้อ
# 13                         มีเวลาน้อยไม่สามารถต่อคิวได้
# 14                                   อาหารที่อยากกินหมด
# 15                      ถ้าคิวยาวเกินจะเลือกร้านอื่นแทน
# 16                            เบื่ื่อร้านอาหารที่มีอยู่
# 17                                      ไม่รู้จะกินอะไร
# 18                                 ไม่มีโต๊ะนั้งกินข้าว
# 19                                      กินอาหารน้อยลง
# 20                              อยากกินร้านอาหารข้างนอก
# 21                                  ร้านอาหารมีคิวเยอะ
# 22              เลิกเรียนช้า ทำให้ไม่เหลืออะไรให้กินเลย
# 23                                 มีเวลาพักกินข้าวน้อย
# 24                                  ไม่อยากกินอาหารจำเจ
# 25                                 ไม่มีอาหารที่อยากกิน
# 26                                     หาโต๊ะนั้งไม่ได้
# 27                               ไม่ชอบกลิ่นที่โรงอาหาร
# 28    คณะอื่นเยอะมาก อาหารซ้ำซาก บางทีอยากกินแถวซอยห...
# 29               ควันเยอะ, ร้อน, แมลงวัน ไม่ค่อยน่านั่ง
# 30                                     คนเยอะ ต่อคิวนาน
# 31              อาจาร์ยสอนเกินเวลาไม่มีอาหารเหลือให้กิน
# 32                                       ขี้เกียจต่อแถว
# 33                  คนเยอะ เบื่ออาหารในคณะ วุ่นวาย ร้อน
# 34                     มาทำงานวันหยุดไม่มีร้านอาหารเปิด
# 35                      ทำงานดึกทำให้ไม่มีร้านอาหารเปิด
# 36        ร้านอาหารมีจำนวนไม่มากพอที่จะรับจำนวนนักศึกษา
# 37                                            โดนลัดคิว
# 38    ต่อคิวนาน คนเยอะมาก เนื่องจากหลายคณะมากินโรงอา...
# 39          ควันที่ร้านข้าวตามสั่งทำเยอะทำให้ไม่อยากกิน
# 40                                      ไม่รู้จะกินอะไร
# 41                                    ที่ร้านลืมออเดอร์
# 42                           ร้านจำไม่ได้ว่าเราสั่งอะไร
# 43                                เบื่ออาหารที่โรงอาหาร
# 44                   ร้านอาหารไม่เปิดให้บริการในเวลาดึก
# 45                          ไม่มีร้านอาหารเปิดในวันหยุด
# 46                                     วัตถุดิบที่ทำหมด
# 47                         ลืมกระเป๋าตังไม่มีเงินสดจ่าย
# 48                                        ร้านไม่รับโอน
# 49                        โรงอาหารคนเยอะไม่มีโต๊ะให้นัง
# 50                   ที่่นั้งไม่เพียงพอกับจำนวนนักศึกษา
# 51                               เดินทางไปโรงอาหารลำบาก
# 52                                  ไม่มีเมนูที่อยากทาน
# 53                                   ร้านอาหารมีคิวเยอะ
# 54                      ร้านอาหารไม่เปิดบริการในวันหยุด
# 55                                 มีเวลาพักไม่พอต่อคิว
# 56                      บรรยากาศโรงอาหารไม่น่ารับประทาน
# 57                  สภาพอากาศทำให้ไม่สามารถออกไปซื้อได้
# Name: Problem, dtype: object

# %%
sentences = []
for x in text:
    proc = word_tokenize(x, engine='newmm')
#     print(proc[0] == " ")
    lst = []
    for word in proc:
        if(word != " "):
            lst.append(word)
    sentences.append(lst)
sentences
# Out:
# [['ถ้า', 'คน', 'เยอะ', 'ก็', 'ไม่', 'อยาก', 'ไป', 'ต่อ', 'คิว'],
#  ['ไม่', '่', 'มี', 'อะไร', 'น่ากิน'],
#  ['ถ้า', 'คิว', 'ยาว', 'ก็', 'ไม่', 'ซื้อ'],
#  ['ถ้า',
#   'ร้าน',
#   'นั้น',
#   'คน',
#   'เยอะ',
#   'ก็',
#   'จะ',
#   'ไป',
#   'เลือก',
#   'ร้าน',
#   'อื่น'],
#  ['ถ้า', 'แถว', 'ยาว', 'มาก', 'ก็', 'จะ', 'ขี้เกียจ', 'รอ'],
#  ['ถ้า', 'คน', 'เยอะ', 'มาก', 'ก็', 'เปลี่ยน', 'ร้าน', 'ไม่', 'อยาก', 'รอ'],
#  ['ถ้า',
#   'คน',
#   'เยอะ',
#   'เกินไป',
#   'ก็',
#   'จะ',
#   'ไม่',
#   'ซื้อ',
#   'เปลี่ยน',
#   'ร้าน',
#   'หรือไม่',
#   'กิน',
#   'เลย'],
#  ['ไม่มี', 'ร้านอาหาร', 'ที่', 'ชอบ'],
#  ['ขี้เกียจ', 'รอ', 'นานๆ', 'แล้ว', 'รู้สึก', 'ว่า', 'มัน', 'เสียเวลา'],
#  ['ถ้า', 'คิว', 'ยาว', 'เกิน', 'จะ', 'เลือก', 'ร้าน', 'อื่น', 'แทน'],
#  ['เบื่อ', 'ร้านอาหาร', 'ที่', 'มี', 'อยู่'],
#  ['อยาก', 'กิน', 'อาหาร', 'แปลกใหม่'],
#  ['โรงอาหาร', 'คน', 'เยอะ', 'ทำให้', 'ไม่', 'อยาก', 'ซื้อ'],
#  ['มี', 'เวลา', 'น้อย', 'ไม่', 'สามารถ', 'ต่อ', 'คิว', 'ได้'],
#  ['อาหาร', 'ที่', 'อยาก', 'กิน', 'หมด'],
#  ['ถ้า', 'คิว', 'ยาว', 'เกิน', 'จะ', 'เลือก', 'ร้าน', 'อื่น', 'แทน'],
#  ['เบื่ื่อ', 'ร้านอาหาร', 'ที่', 'มี', 'อยู่'],
#  ['ไม่รู้', 'จะ', 'กิน', 'อะไร'],
#  ['ไม่มี', 'โต๊ะ', 'นั้ง', 'กินข้าว'],
#  ['กิน', 'อาหาร', 'น้อยลง'],
#  ['อยาก', 'กิน', 'ร้านอาหาร', 'ข้างนอก'],
#  ['ร้านอาหาร', 'มี', 'คิว', 'เยอะ'],
#  ['เลิกเรียน', 'ช้า', 'ทำให้', 'ไม่', 'เหลือ', 'อะไร', 'ให้', 'กิน', 'เลย'],
#  ['มี', 'เวลา', 'พัก', 'กินข้าว', 'น้อย'],
#  ['ไม่', 'อยาก', 'กิน', 'อาหาร', 'จำเจ'],
#  ['ไม่มี', 'อาหาร', 'ที่', 'อยาก', 'กิน'],
#  ['หา', 'โต๊ะ', 'นั้ง', 'ไม่ได้'],
#  ['ไม่', 'ชอบ', 'กลิ่น', 'ที่', 'โรงอาหาร'],
#  ['คณะ',
#   'อื่น',
#   'เยอะ',
#   'มาก',
#   'อาหาร',
#   'ซ้ำซาก',
#   'บางที',
#   'อยาก',
#   'กินแถว',
#   'ซอย',
#   'หอ',
#   'แต่',
#   'เวลา',
#   'ก็',
#   'ไม่ค่อย',
#   'พอ',
#   'เลย',
#   'ต้อง',
#   'กินใน',
#   'คณะ',
#   'ไป',
#   'ก่อน',
#   'โรงอาหาร',
#   'ร้อน',
#   'มาก',
#   'และ',
#   'อบ',
#   'มาก'],
#  ['ควัน', 'เยอะ', ',', 'ร้อน', ',', 'แมลงวัน', 'ไม่ค่อย', 'น่า', 'นั่ง'],
#  ['คน', 'เยอะ', 'ต่อ', 'คิว', 'นาน'],
#  ['อาจาร',
#   '์ย',
#   'สอน',
#   'เกิน',
#   'เวลา',
#   'ไม่มี',
#   'อาหาร',
#   'เหลือ',
#   'ให้',
#   'กิน'],
#  ['ขี้เกียจ', 'ต่อ', 'แถว'],
#  ['คน', 'เยอะ', 'เบื่ออาหาร', 'ใน', 'คณะ', 'วุ่นวาย', 'ร้อน'],
#  ['มา', 'ทำงาน', 'วันหยุด', 'ไม่มี', 'ร้านอาหาร', 'เปิด'],
#  ['ทำงาน', 'ดึก', 'ทำให้', 'ไม่มี', 'ร้านอาหาร', 'เปิด'],
#  ['ร้านอาหาร',
#   'มี',
#   'จำนวน',
#   'ไม่',
#   'มาก',
#   'พอที่จะ',
#   'รับ',
#   'จำนวน',
#   'นักศึกษา'],
#  ['โดน', 'ลัด', 'คิว'],
#  ['ต่อ',
#   'คิว',
#   'นาน',
#   'คน',
#   'เยอะ',
#   'มาก',
#   'เนื่องจาก',
#   'หลาย',
#   'คณะ',
#   'มา',
#   'กิน',
#   'โรงอาหาร',
#   'เดียว',
#   'กับ',
#   'เรา',
#   'ทำให้',
#   'บาง',
#   'ร้าน',
#   'ต้อง',
#   'รอ',
#   'คิว',
#   'นาน',
#   'และ',
#   'อาหาร',
#   'ไม่ค่อย',
#   'หลากหลาย'],
#  ['ควัน',
#   'ที่',
#   'ร้าน',
#   'ข้าว',
#   'ตาม',
#   'สั่งทำ',
#   'เยอะ',
#   'ทำให้',
#   'ไม่',
#   'อยาก',
#   'กิน'],
#  ['ไม่รู้', 'จะ', 'กิน', 'อะไร'],
#  ['ที่', 'ร้าน', 'ลืม', 'ออเดอร์'],
#  ['ร้าน', 'จำ', 'ไม่ได้', 'ว่า', 'เรา', 'สั่ง', 'อะไร'],
#  ['เบื่ออาหาร', 'ที่', 'โรงอาหาร'],
#  ['ร้านอาหาร', 'ไม่', 'เปิด', 'ให้บริการ', 'ใน', 'เวลา', 'ดึก'],
#  ['ไม่มี', 'ร้านอาหาร', 'เปิด', 'ใน', 'วันหยุด'],
#  ['วัตถุดิบ', 'ที่', 'ทำ', 'หมด'],
#  ['ลืม', 'กระเป๋า', 'ตัง', 'ไม่มี', 'เงินสด', 'จ่าย'],
#  ['ร้าน', 'ไม่', 'รับ', 'โอน'],
#  ['โรงอาหาร', 'คน', 'เยอะ', 'ไม่มี', 'โต๊ะ', 'ให้', 'นัง'],
#  ['ที่', '่นั้ง', 'ไม่', 'เพียง', 'พอกับ', 'จำนวน', 'นักศึกษา'],
#  ['เดินทาง', 'ไป', 'โรงอาหาร', 'ลำบาก'],
#  ['ไม่มี', 'เมนู', 'ที่', 'อยาก', 'ทาน'],
#  ['ร้านอาหาร', 'มี', 'คิว', 'เยอะ'],
#  ['ร้านอาหาร', 'ไม่', 'เปิด', 'บริการ', 'ใน', 'วันหยุด'],
#  ['มี', 'เวลา', 'พัก', 'ไม่พอ', 'ต่อ', 'คิว'],
#  ['บรรยากาศ', 'โรงอาหาร', 'ไม่', 'น่ารับประทาน'],
#  ['สภาพอากาศ', 'ทำให้', 'ไม่', 'สามารถ', 'ออก', 'ไป', 'ซื้อ', 'ได้']]

# %%
model_nlp = pythainlp.word_vector.get_model()

# %%
def sentence_vectorizer(ss,dim=300,use_mean=True): # ประกาศฟังก์ชัน sentence_vectorizer
    s = word_tokenize(ss)
    vec = np.zeros((1,dim))
    for word in s:
        if word in model_nlp.wv.index2word: 
            vec+= model_nlp.wv.word_vec(word)
        else: pass
    if use_mean: vec /= len(s)
    return vec

lst_vector = []
for i in text:
    lst_vector.append(sentence_vectorizer(i)[0])
X=np.array(lst_vector)
print(X)
# Out:
# c:\users\pack.apichart\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# c:\users\pack.apichart\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
# [[-0.1005676  -0.1279158   0.1434774  ...  0.27638691 -0.1700624
#   -0.47342749]
#  [ 0.1502752  -0.1439068   0.3079486  ... -0.0775482  -0.173492
#   -0.066201  ]
#  [-0.02242983 -0.08485817  0.07547517 ...  0.18557817 -0.09975701
#   -0.37882982]
#  ...
#  [-0.27691783 -0.23883267  0.121165   ...  0.1382745  -0.20913566
#   -0.10442933]
#  [-0.01261225  0.06232125  0.09211525 ... -0.13062624 -0.0026475
#   -0.1373365 ]
#  [-0.16045525 -0.21322238  0.11755663 ...  0.20350088 -0.183952
#   -0.39366462]]

# %% [markdown]
# ### Elbow Algorithm
# * find the best cluster

# %%
import matplotlib.pyplot as plt
wcss = []
for i in range(1,11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1,11), wcss)
plt.title('Elbow')
plt.xlabel('Num')
plt.ylabel('WCSS')
plt.show()

# %% [markdown]
# ### Create Model Kmean

# %%
n_clusters = 5
clf = KMeans(n_clusters=n_clusters,
            max_iter=100,
            init='k-means++',
            n_init=1)
labels = clf.fit_predict(X)
labels
# Out:
# array([4, 0, 4, 4, 4, 4, 4, 3, 4, 4, 3, 2, 4, 1, 2, 4, 3, 2, 0, 2, 2, 0,
#        4, 1, 2, 2, 0, 3, 4, 0, 4, 0, 4, 0, 0, 0, 0, 0, 4, 4, 2, 3, 4, 3,
#        0, 0, 3, 0, 0, 0, 3, 4, 3, 0, 0, 1, 0, 1])

# %%
cluster = []
value = []
o = ""
for index, sentence in enumerate(sentences):
#     print(str(labels[index]) + ":" + str(sentence))
    cluster.append(labels[index])
    value.append(o.join(sentences[index]))
list_of_cluster = list(zip(cluster,value))
df_cluster = pd.DataFrame(list_of_cluster, columns = ['cluster', 'text'])  
df_cluster
# Out:
#     cluster                                               text
# 0         4                         ถ้าคนเยอะก็ไม่อยากไปต่อคิว
# 1         0                                   ไม่่มีอะไรน่ากิน
# 2         4                                 ถ้าคิวยาวก็ไม่ซื้อ
# 3         4               ถ้าร้านนั้นคนเยอะก็จะไปเลือกร้านอื่น
# 4         4                         ถ้าแถวยาวมากก็จะขี้เกียจรอ
# 5         4                 ถ้าคนเยอะมากก็เปลี่ยนร้านไม่อยากรอ
# 6         4  ถ้าคนเยอะเกินไปก็จะไม่ซื้อเปลี่ยนร้านหรือไม่กิ...
# 7         3                               ไม่มีร้านอาหารที่ชอบ
# 8         4             ขี้เกียจรอนานๆแล้วรู้สึกว่ามันเสียเวลา
# 9         4                    ถ้าคิวยาวเกินจะเลือกร้านอื่นแทน
# 10        3                            เบื่อร้านอาหารที่มีอยู่
# 11        2                               อยากกินอาหารแปลกใหม่
# 12        4                     โรงอาหารคนเยอะทำให้ไม่อยากซื้อ
# 13        1                       มีเวลาน้อยไม่สามารถต่อคิวได้
# 14        2                                 อาหารที่อยากกินหมด
# 15        4                    ถ้าคิวยาวเกินจะเลือกร้านอื่นแทน
# 16        3                          เบื่ื่อร้านอาหารที่มีอยู่
# 17        2                                    ไม่รู้จะกินอะไร
# 18        0                               ไม่มีโต๊ะนั้งกินข้าว
# 19        2                                     กินอาหารน้อยลง
# 20        2                            อยากกินร้านอาหารข้างนอก
# 21        0                                 ร้านอาหารมีคิวเยอะ
# 22        4             เลิกเรียนช้าทำให้ไม่เหลืออะไรให้กินเลย
# 23        1                               มีเวลาพักกินข้าวน้อย
# 24        2                                ไม่อยากกินอาหารจำเจ
# 25        2                               ไม่มีอาหารที่อยากกิน
# 26        0                                   หาโต๊ะนั้งไม่ได้
# 27        3                             ไม่ชอบกลิ่นที่โรงอาหาร
# 28        4  คณะอื่นเยอะมากอาหารซ้ำซากบางทีอยากกินแถวซอยหอแ...
# 29        0                ควันเยอะ,ร้อน,แมลงวันไม่ค่อยน่านั่ง
# 30        4                                    คนเยอะต่อคิวนาน
# 31        0            อาจาร์ยสอนเกินเวลาไม่มีอาหารเหลือให้กิน
# 32        4                                     ขี้เกียจต่อแถว
# 33        0                   คนเยอะเบื่ออาหารในคณะวุ่นวายร้อน
# 34        0                   มาทำงานวันหยุดไม่มีร้านอาหารเปิด
# 35        0                    ทำงานดึกทำให้ไม่มีร้านอาหารเปิด
# 36        0      ร้านอาหารมีจำนวนไม่มากพอที่จะรับจำนวนนักศึกษา
# 37        0                                          โดนลัดคิว
# 38        4  ต่อคิวนานคนเยอะมากเนื่องจากหลายคณะมากินโรงอาหา...
# 39        4        ควันที่ร้านข้าวตามสั่งทำเยอะทำให้ไม่อยากกิน
# 40        2                                    ไม่รู้จะกินอะไร
# 41        3                                  ที่ร้านลืมออเดอร์
# 42        4                         ร้านจำไม่ได้ว่าเราสั่งอะไร
# 43        3                              เบื่ออาหารที่โรงอาหาร
# 44        0                 ร้านอาหารไม่เปิดให้บริการในเวลาดึก
# 45        0                        ไม่มีร้านอาหารเปิดในวันหยุด
# 46        3                                   วัตถุดิบที่ทำหมด
# 47        0                       ลืมกระเป๋าตังไม่มีเงินสดจ่าย
# 48        0                                      ร้านไม่รับโอน
# 49        0                      โรงอาหารคนเยอะไม่มีโต๊ะให้นัง
# 50        3                 ที่่นั้งไม่เพียงพอกับจำนวนนักศึกษา
# 51        4                             เดินทางไปโรงอาหารลำบาก
# 52        3                                ไม่มีเมนูที่อยากทาน
# 53        0                                 ร้านอาหารมีคิวเยอะ
# 54        0                    ร้านอาหารไม่เปิดบริการในวันหยุด
# 55        1                               มีเวลาพักไม่พอต่อคิว
# 56        0                    บรรยากาศโรงอาหารไม่น่ารับประทาน
# 57        1                สภาพอากาศทำให้ไม่สามารถออกไปซื้อได้

# %% [markdown]
# ### speech_recognition

# %%
import speech_recognition as sr
# Record Audio
r = sr.Recognizer()
m = sr.Microphone()

# %%
#set threhold level
with m as source: r.adjust_for_ambient_noise(source)
print("Set minimum energy threshold to {}".format(r.energy_threshold))

# Speech recognition using Google Speech Recognition
def checkspeech(r):
#     file_wav
#     sr.Microphone()  sr.WavFile(file_wav)
#     with sr.WavFile("C:/Users/Pack.Apichart/Desktop/re/t1.wav")
    print("Wake UP!!")
    with  sr.Microphone()  as source:
        audio = r.listen(source)
    try:
    # for testing purposes, we're just using the default API key
    # to use another API key, use `r.recognize_google(audio, key="GOOGLE_SPEECH_RECOGNITION_API_KEY")`
    # instead of `r.recognize_google(audio)`

# "en-US"
# "th-TH"
        print("You said: " + r.recognize_google(audio,language = "th-TH"))
        return r.recognize_google(audio,language = "th-TH")
#         return (r.recognize_google(audio))
    except sr.UnknownValueError:
        print("Google Speech Recognition could not understand audio")
        return "stop now"
    except sr.RequestError as e:
        print("Could not request results from Google Speech Recognition service; {0}".format(e))
        return []

# speech = str(checkspeech(r))
# Out:
# Set minimum energy threshold to 63.338161204736615

# %%
speech_list = []
speech = str(checkspeech(r))
# Out:
# Wake UP!!
# You said: เบื่ออาหารครับ

# %%
speech_list.append(sentence_vectorizer(str(speech))[0])
speech_vector = np.array(speech_list)
result = clf.predict(speech_vector)
result
# Out:
# c:\users\pack.apichart\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# c:\users\pack.apichart\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
# array([0])

# %% [markdown]
# ### Same cluster speech

# %%
df_cluster[df_cluster['cluster'] == result.item(0)]
# Out:
#     cluster                                           text
# 1         0                               ไม่่มีอะไรน่ากิน
# 18        0                           ไม่มีโต๊ะนั้งกินข้าว
# 21        0                             ร้านอาหารมีคิวเยอะ
# 26        0                               หาโต๊ะนั้งไม่ได้
# 29        0            ควันเยอะ,ร้อน,แมลงวันไม่ค่อยน่านั่ง
# 31        0        อาจาร์ยสอนเกินเวลาไม่มีอาหารเหลือให้กิน
# 33        0               คนเยอะเบื่ออาหารในคณะวุ่นวายร้อน
# 34        0               มาทำงานวันหยุดไม่มีร้านอาหารเปิด
# 35        0                ทำงานดึกทำให้ไม่มีร้านอาหารเปิด
# 36        0  ร้านอาหารมีจำนวนไม่มากพอที่จะรับจำนวนนักศึกษา
# 37        0                                      โดนลัดคิว
# 44        0             ร้านอาหารไม่เปิดให้บริการในเวลาดึก
# 45        0                    ไม่มีร้านอาหารเปิดในวันหยุด
# 47        0                   ลืมกระเป๋าตังไม่มีเงินสดจ่าย
# 48        0                                  ร้านไม่รับโอน
# 49        0                  โรงอาหารคนเยอะไม่มีโต๊ะให้นัง
# 53        0                             ร้านอาหารมีคิวเยอะ
# 54        0                ร้านอาหารไม่เปิดบริการในวันหยุด
# 56        0                บรรยากาศโรงอาหารไม่น่ารับประทาน

# %%
# def sentence_similarity(s1,s2):
#     for i in s2:
#         print(cosine_similarity(sentence_vectorizer(str(s1)),sentence_vectorizer(str(i))))
# #     return cosine_similarity(sentence_vectorizer(str(s1)),sentence_vectorizer(str(s2)))

# %%
# test_word = ["อยากกินร้านอาหารข้างนอก"]
# sentence_similarity(speech, test_word)

# %% [markdown]
# ### PCA

# %%
# pca  = PCA(n_components=2).fit(X)
# coords = pca.transform(X)
# label_colors = ["#54FF9F", "#7D26CD", "#794044", "#F4E628","#54a1ff","#22d6c4","#22d6c4","#d65522","#cf1351"]
# colors = [label_colors[i] for i in labels]
# plt.scatter(coords[:, 0], coords[:, 1], c=colors)
# centroids = clf.cluster_centers_
# centroid_coords = pca.transform(centroids)
# plt.scatter(centroid_coords[:, 0], centroid_coords[:, 1], marker='X', s=200, linewidths=2, c='#444d61')
# plt.show()
